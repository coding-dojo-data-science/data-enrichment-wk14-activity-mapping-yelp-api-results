# %% [markdown]
# # Part 1 - Extracting and Saving Data from Yelp API

# %% [markdown]
# ## Obective

# %% [markdown]
# - For this CodeAlong, we will be working with the Yelp API.
# - You will use the the Yelp API to search your home town for a cuisine type of your choice.
# - Next class, we will then use Plotly Express to create a map with the Mapbox API to visualize the results.

# %% [markdown]
# ## Tools You Will Use
# - Part 1:
#     - Yelp API:
#         - Getting Started:
#             - https://www.yelp.com/developers/documentation/v3/get_started
#
#     - `YelpAPI` python package
#         -  "YelpAPI": https://github.com/gfairchild/yelpapi
# - Part 2:
#
#     - Plotly Express: https://plotly.com/python/getting-started/
#         - With Mapbox API: https://www.mapbox.com/
#         - `px.scatter_mapbox` [Documentation](https://plotly.com/python/scattermapbox/):

# %% [markdown]
# ### Applying Code From
# - Efficient API Calls Lesson Link: https://login.codingdojo.com/m/376/12529/88078

# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Additional Imports
import os, json, math, time
from yelpapi import YelpAPI
from tqdm.notebook import tqdm_notebook

# %% [markdown]
# ## 1. Registering for Required APIs

# %% [markdown]
# - Yelp: https://www.yelp.com/developers/documentation/v3/get_started

# %% [markdown]
# > Check the official API documentation to know what arguments we can search for: https://www.yelp.com/developers/documentation/v3/business_search

# %% [markdown]
# ### Load Credentials and Create Yelp API Object

# %%
# Load API Credentials
with open('/Users/purvikansara/.secret/yelp_api.json') as f:
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['Client-ID', 'API Key'])

# %%
# Instantiate YelpAPI Variable
yelp = YelpAPI(login['API Key'],timeout_s=5.0)

# %% [markdown]
# ### Define Search Terms and File Paths

# %%
# set our API call parameters and filename before the first call
location  = 'Seattle, WA 98122'
term = 'pizza'

# %%
location.split(',')[0]
# Out:
# 'Seattle'

# %%
## Specify fodler for saving data

FOLDER = 'Data/'
os.makedirs(FOLDER,exist_ok=True)
# Specifying JSON_FILE filename (can include a folder)
#JSON_FILE = FOLDER+'Seattle pizza.json'


JSON_FILE =FOLDER+f"{location.split(',')[0]}-{term}.json"

# %%
JSON_FILE
# Out:
# 'Data/Seattle-pizza.json'

# %% [markdown]
# ### Make the first API call to get the first page of data

# %% [markdown]
# - We will use this first result to check:
#     - how many total results there are?
#     - Where is the actual data we want to save?
#     - how many results do we get at a time?

# %%
# use our yelp_api variable's search_query method to perform our API call

results =yelp.search_query(term=term,location=location)

type(results)
# Out:
# dict

# %%
results
# Out:
# {'businesses': [{'id': 't-Z9bvmlgUyDtomGmttrUQ',
#    'alias': 'guerilla-pizza-kitchen-seattle',
#    'name': 'Guerilla Pizza Kitchen',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/uMrdEjc9J_4Tb1PtAb71UA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/guerilla-pizza-kitchen-seattle?adjust_creative=r8Qlusnw5U_OXTmzDH90Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=r8Qlusnw5U_OXTmzDH90Ug',
#    'review_count': 1,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'popuprestaurants', 'title': 'Pop-Up Restaurants'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 47.608127, 'longitude': -122.302435},
#    'transactions': [],
#    'location': {'address1': '2300 E Cherry St',
#     'address2': '',
#     'address3': None,
#     'city': 'Seattle',
#     'zip_code': '98122',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['2300 E Cherry St', 'Seattle, WA 98122']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 749.1731129459927},
#   {'id': 'Wi6LFkjIausYj277ru6pqg',
#    'alias': 'humble-pie-seattle',
#    'name': 'Humble Pie',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9tK83_pyCwNnRE7wMbNQdQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/humble-pie-seattle?adjust_creative=r8Qlusnw5U_OXTmzDH90Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=r8Qlusnw5U_OXTmzDH90Ug',
#    'review_count': 349,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.5976491915013,
#     'longitude': -122.313305988361},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '525 Rainier Ave S',
#     'address2': '',
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98144',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['525 Rainier Ave S', 'Seattle, WA 98144']},
#    'phone': '+12063295133',
#    'display_phone': '(206) 329-5133',
#    'distance': 2166.834011449786},
#   {'id': 'EwrAoy7XbX8nfemZdDvupA',
#    'alias': 'cornelly-seattle',
#    'name': 'Cornelly',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/HlYYBTxylVQf6C-WZy-Ghw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cornelly-seattle?adjust_creative=r8Qlusnw5U_OXTmzDH90Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=r8Qlusnw5U_OXTmzDH90Ug',
#    'review_count': 86,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'pastashops', 'title': 'Pasta Shops'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 47.624577, 'longitude': -122.325577},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '601 Summit Ave E',
#     'address2': '',
#     'address3': None,
#     'city': 'Seattle',
#     'zip_code': '98102',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['601 Summit Ave E', 'Seattle, WA 98102']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2578.701392645466},
#   {'id': 'fxyHWmfzcdjImgQ_UYHoTw',
#    'alias': 'bar-cotto-seattle',
#    'name': 'Bar Cotto',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/07DoPFljyge3LApw8qW-cg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bar-cotto-seattle?adjust_creative=r8Qlusnw5U_OXTmzDH90Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=r8Qlusnw5U_OXTmzDH90Ug',
#    'review_count': 330,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 47.6146934, 'longitude': -122.3127642},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '1546 15th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98122',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['1546 15th Ave', 'Seattle, WA 98122']},
#    'phone': '+12068388081',
#    'display_phone': '(206) 838-8081',
#    'distance': 1292.526796461093},
#   {'id': 'M9xzvwgK58T0w7wvXedvuQ',
#    'alias': 'hot-mamas-pizza-seattle',
#    'name': "Hot Mama's Pizza",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/LEL1qjUtdXO8aUPV9U-WwQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hot-mamas-pizza-seattle?adjust_creative=r8Qlusnw5U_OXTmzDH90Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=r8Qlusnw5U_OXTmzDH90Ug',
#    'review_count': 925,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.615379179632, 'longitude': -122.32323073437},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '700 E Pine St',
#     'address2': '',
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98122',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['700 E Pine St', 'Seattle, WA 98122']},
#    'phone': '+12063226444',
#    'display_phone': '(206) 322-6444',
#    'distance': 2080.359405276959},
#   {'id': 'FVbwpNA1uZEGiM02N4XtUg',
#    'alias': 'blotto-seattle',
#    'name': 'Blotto',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Q4Y1CwKmapk89MYpoxCu7Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blotto-seattle?adjust_creative=r8Qlusnw5U_OXTmzDH90Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=r8Qlusnw5U_OXTmzDH90Ug',
#    'review_count': 30,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 47.61849, 'longitude': -122.31664},
#    'transactions': [],
#    'location': {'address1': '1830 12th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Seattle',
#     'zip_code': '98122',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['1830 12th Ave', 'Seattle, WA 98122']},
#    'phone': '+12064031809',
#    'display_phone': '(206) 403-1809',
#    'distance': 1686.8621759079958},
#   {'id': 'ugTsEtjvwRhteac_6JcuPw',
#    'alias': 'italian-family-pizza-seattle',
#    'name': 'Italian Family Pizza',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SgiSrJxdCGbPZjnTZRrCYQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/italian-family-pizza-seattle?adjust_creative=r8Qlusnw5U_OXTmzDH90Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=r8Qlusnw5U_OXTmzDH90Ug',
#    'review_count': 972,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.60937, 'longitude': -122.32546},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1028 Madison St',
#     'address2': None,
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98104',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['1028 Madison St', 'Seattle, WA 98104']},
#    'phone': '+12065380040',
#    'display_phone': '(206) 538-0040',
#    'distance': 2271.307105309817},
#   {'id': 'et4eWK49x5od4lfqCukG6w',
#    'alias': 'central-pizza-seattle',
#    'name': 'Central Pizza',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/DE4G4eOtt4lcBN_PJtaniw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/central-pizza-seattle?adjust_creative=r8Qlusnw5U_OXTmzDH90Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=r8Qlusnw5U_OXTmzDH90Ug',
#    'review_count': 191,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.598976, 'longitude': -122.294685},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2901 S Jackson St',
#     'address2': '',
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98144',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['2901 S Jackson St', 'Seattle, WA 98144']},
#    'phone': '+12066026333',
#    'display_phone': '(206) 602-6333',
#    'distance': 1571.8674380755467},
#   {'id': 'cAFXng3Gr1cBCFkP1VIxng',
#    'alias': 'the-independent-pizzeria-seattle-2',
#    'name': 'The Independent Pizzeria',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/4gIuisTnhbj8O3O09yLcrg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-independent-pizzeria-seattle-2?adjust_creative=r8Qlusnw5U_OXTmzDH90Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=r8Qlusnw5U_OXTmzDH90Ug',
#    'review_count': 179,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.636044, 'longitude': -122.277377},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '4235 E Madison St',
#     'address2': '',
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98112',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['4235 E Madison St', 'Seattle, WA 98112']},
#    'phone': '+12068606110',
#    'display_phone': '(206) 860-6110',
#    'distance': 2897.2528438366567},
#   {'id': 'IrohtoYjnAR_vc6w6CRCxA',
#    'alias': 'moto-seattle',
#    'name': 'Moto',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FBmvjyC1wH7-N_lIE_M_lQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/moto-seattle?adjust_creative=r8Qlusnw5U_OXTmzDH90Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=r8Qlusnw5U_OXTmzDH90Ug',
#    'review_count': 110,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 47.56207, 'longitude': -122.38509},
#    'transactions': ['delivery'],
#    'location': {'address1': '4526 42nd Ave SW',
#     'address2': '',
#     'address3': None,
#     'city': 'Seattle',
#     'zip_code': '98116',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['4526 42nd Ave SW', 'Seattle, WA 98116']},
#    'phone': '+12064208880',
#    'display_phone': '(206) 420-8880',
#    'distance': 8784.07572205985},
#   {'id': '7hfyyyVKXOQMOMWTkFrvNg',
#    'alias': 'boca-argentine-bakery-and-pizzeria-seattle',
#    'name': 'Boca Argentine Bakery & Pizzeria',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5MPTtVa-2QR5WWt5zBXpDg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boca-argentine-bakery-and-pizzeria-seattle?adjust_creative=r8Qlusnw5U_OXTmzDH90Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=r8Qlusnw5U_OXTmzDH90Ug',
#    'review_count': 16,
#    'categories': [{'alias': 'argentine', 'title': 'Argentine'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 47.62278, 'longitude': -122.32064},
#    'transactions': [],
#    'location': {'address1': '426 Broadway E',
#     'address2': '',
#     'address3': None,
#     'city': 'Seattle',
#     'zip_code': '98102',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['426 Broadway E', 'Seattle, WA 98102']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2152.6791116688687},
#   {'id': '91q2mxR0R6d-HAHFnmePyg',
#    'alias': 'zeeks-pizza-seattle-18',
#    'name': 'Zeeks Pizza',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qmf4kAK54g5IHoPYUDbYDg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zeeks-pizza-seattle-18?adjust_creative=r8Qlusnw5U_OXTmzDH90Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=r8Qlusnw5U_OXTmzDH90Ug',
#    'review_count': 89,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.6245449, 'longitude': -122.3081645},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '1830 E Mercer St',
#     'address2': None,
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98112',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['1830 E Mercer St', 'Seattle, WA 98112']},
#    'phone': '+12062858646',
#    'display_phone': '(206) 285-8646',
#    'distance': 1554.2138613942195},
#   {'id': '1rkgyfwzXG7qSdVZdfRt7g',
#    'alias': 'roccos-seattle',
#    'name': "Rocco's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/pf6jTKEQp89tKYy0OzB6Gw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/roccos-seattle?adjust_creative=r8Qlusnw5U_OXTmzDH90Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=r8Qlusnw5U_OXTmzDH90Ug',
#    'review_count': 1686,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.614470434736106,
#     'longitude': -122.34606443927872},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2312 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98121',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['2312 2nd Ave', 'Seattle, WA 98121']},
#    'phone': '+12063974210',
#    'display_phone': '(206) 397-4210',
#    'distance': 3779.508799794575},
#   {'id': '-FOAQv22SXtSBs7nptI3UA',
#    'alias': 'serious-pie-downtown-seattle-2',
#    'name': 'Serious Pie Downtown',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dy0pJ5hIEX5APuotqrgF7A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/serious-pie-downtown-seattle-2?adjust_creative=r8Qlusnw5U_OXTmzDH90Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=r8Qlusnw5U_OXTmzDH90Ug',
#    'review_count': 4399,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.61304626911818,
#     'longitude': -122.34035259077139},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2001 4th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98121',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['2001 4th Ave', 'Seattle, WA 98121']},
#    'phone': '+12068387388',
#    'display_phone': '(206) 838-7388',
#    'distance': 3348.3092758278417},
#   {'id': 'n6BLr6spgjVWqzUwmVx0bg',
#    'alias': 'johnny-mos-pizzeria-seattle',
#    'name': "Johnny Mo's Pizzeria",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/8IAnDPt0FWQNx9pLvuSbNg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/johnny-mos-pizzeria-seattle?adjust_creative=r8Qlusnw5U_OXTmzDH90Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=r8Qlusnw5U_OXTmzDH90Ug',
#    'review_count': 120,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 47.65142, 'longitude': -122.32083},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '3272 Fuhrman Ave E',
#     'address2': 'Ste 100',
#     'address3': None,
#     'city': 'Seattle',
#     'zip_code': '98102',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['3272 Fuhrman Ave E', 'Ste 100', 'Seattle, WA 98102']},
#    'phone': '+12068226272',
#    'display_phone': '(206) 822-6272',
#    'distance': 4658.301257471318},
#   {'id': 'slbmD92j1JKShUa0InF2nw',
#    'alias': 'southpaw-seattle',
#    'name': 'Southpaw',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rJXKQ5Ah6APg5wnqaHM8lg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/southpaw-seattle?adjust_creative=r8Qlusnw5U_OXTmzDH90Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=r8Qlusnw5U_OXTmzDH90Ug',
#    'review_count': 77,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.61118, 'longitude': -122.31654},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '926 12th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Seattle',
#     'zip_code': '98122',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['926 12th Ave', 'Seattle, WA 98122']},
#    'phone': '+12063235278',
#    'display_phone': '(206) 323-5278',
#    'distance': 1576.8742723613634},
#   {'id': 'GJdmwqqkC0nAQfX1qZM3ew',
#    'alias': 'olympia-pizza-and-spaghetti-house-iii-seattle',
#    'name': 'Olympia Pizza and Spaghetti House III',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KvTgMAozPm_HQGaBsfGELQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/olympia-pizza-and-spaghetti-house-iii-seattle?adjust_creative=r8Qlusnw5U_OXTmzDH90Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=r8Qlusnw5U_OXTmzDH90Ug',
#    'review_count': 287,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.62383, 'longitude': -122.312445},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '516 15th Ave E',
#     'address2': '',
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98112',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['516 15th Ave E', 'Seattle, WA 98112']},
#    'phone': '+12063294500',
#    'display_phone': '(206) 329-4500',
#    'distance': 1732.8743834241322},
#   {'id': 'PpAiLhErwd08QhPb06_-hA',
#    'alias': 'mioposto-seattle-7',
#    'name': 'Mioposto',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gWBw_lWXRC-95u0hh796mg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mioposto-seattle-7?adjust_creative=r8Qlusnw5U_OXTmzDH90Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=r8Qlusnw5U_OXTmzDH90Ug',
#    'review_count': 380,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.57802, 'longitude': -122.28808},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '3601 S McClellan St',
#     'address2': None,
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98144',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['3601 S McClellan St', 'Seattle, WA 98144']},
#    'phone': '+12067603400',
#    'display_phone': '(206) 760-3400',
#    'distance': 3941.6634321994184},
#   {'id': 'pE-IY0ESxv67j34JSkdvfg',
#    'alias': 'nine-pies-pizzeria-seattle',
#    'name': 'Nine Pies Pizzeria',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/S-C1c1_8z-xMPS3vP3LCxQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nine-pies-pizzeria-seattle?adjust_creative=r8Qlusnw5U_OXTmzDH90Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=r8Qlusnw5U_OXTmzDH90Ug',
#    'review_count': 139,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 47.5679230496817,
#     'longitude': -122.335252473016},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '3861 1st Ave S',
#     'address2': None,
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98134',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['3861 1st Ave S', 'Seattle, WA 98134']},
#    'phone': '+12065820777',
#    'display_phone': '(206) 582-0777',
#    'distance': 5833.910009420632},
#   {'id': 'k3riaoflafifFUSNKXbfTw',
#    'alias': 'via-tribunali-capitol-hill-seattle',
#    'name': 'Via Tribunali - Capitol Hill',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/8nqcG7vEE_zVsIhHzdZD7Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/via-tribunali-capitol-hill-seattle?adjust_creative=r8Qlusnw5U_OXTmzDH90Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=r8Qlusnw5U_OXTmzDH90Ug',
#    'review_count': 616,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.61386, 'longitude': -122.31986},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '913 E Pike St',
#     'address2': '',
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98122',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['913 E Pike St', 'Seattle, WA 98122']},
#    'phone': '+12063229234',
#    'display_phone': '(206) 322-9234',
#    'distance': 1818.6291786273798}],
#  'total': 844,
#  'region': {'center': {'longitude': -122.29568481445312,
#    'latitude': 47.61309534151991}}}

# %%
results.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
results['businesses'][0]
# Out:
# {'id': 't-Z9bvmlgUyDtomGmttrUQ',
#  'alias': 'guerilla-pizza-kitchen-seattle',
#  'name': 'Guerilla Pizza Kitchen',
#  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/uMrdEjc9J_4Tb1PtAb71UA/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/guerilla-pizza-kitchen-seattle?adjust_creative=r8Qlusnw5U_OXTmzDH90Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=r8Qlusnw5U_OXTmzDH90Ug',
#  'review_count': 1,
#  'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#   {'alias': 'popuprestaurants', 'title': 'Pop-Up Restaurants'}],
#  'rating': 5.0,
#  'coordinates': {'latitude': 47.608127, 'longitude': -122.302435},
#  'transactions': [],
#  'location': {'address1': '2300 E Cherry St',
#   'address2': '',
#   'address3': None,
#   'city': 'Seattle',
#   'zip_code': '98122',
#   'country': 'US',
#   'state': 'WA',
#   'display_address': ['2300 E Cherry St', 'Seattle, WA 98122']},
#  'phone': '',
#  'display_phone': '',
#  'distance': 749.1731129459927}

# %%
pd.DataFrame(results['businesses'])
# Out:
#                         id                                          alias  \
# 0   t-Z9bvmlgUyDtomGmttrUQ                 guerilla-pizza-kitchen-seattle
# 1   Wi6LFkjIausYj277ru6pqg                             humble-pie-seattle
# 2   EwrAoy7XbX8nfemZdDvupA                               cornelly-seattle
# 3   fxyHWmfzcdjImgQ_UYHoTw                              bar-cotto-seattle
# 4   M9xzvwgK58T0w7wvXedvuQ                        hot-mamas-pizza-seattle
# 5   FVbwpNA1uZEGiM02N4XtUg                                 blotto-seattle
# 6   ugTsEtjvwRhteac_6JcuPw                   italian-family-pizza-seattle
# 7   et4eWK49x5od4lfqCukG6w                          central-pizza-seattle
# 8   cAFXng3Gr1cBCFkP1VIxng             the-independent-pizzeria-seattle-2
# 9   IrohtoYjnAR_vc6w6CRCxA                                   moto-seattle
# 10  7hfyyyVKXOQMOMWTkFrvNg     boca-argentine-bakery-and-pizzeria-seattle
# 11  91q2mxR0R6d-HAHFnmePyg                         zeeks-pizza-seattle-18
# 12  1rkgyfwzXG7qSdVZdfRt7g                                 roccos-seattle
# 13  -FOAQv22SXtSBs7nptI3UA                 serious-pie-downtown-seattle-2
# 14  n6BLr6spgjVWqzUwmVx0bg                    johnny-mos-pizzeria-seattle
# 15  slbmD92j1JKShUa0InF2nw                               southpaw-seattle
# 16  GJdmwqqkC0nAQfX1qZM3ew  olympia-pizza-and-spaghetti-house-iii-seattle
# 17  PpAiLhErwd08QhPb06_-hA                             mioposto-seattle-7
# 18  pE-IY0ESxv67j34JSkdvfg                     nine-pies-pizzeria-seattle
# 19  k3riaoflafifFUSNKXbfTw             via-tribunali-capitol-hill-seattle
#
#                                      name  \
# 0                  Guerilla Pizza Kitchen
# 1                              Humble Pie
# 2                                Cornelly
# 3                               Bar Cotto
# 4                        Hot Mama's Pizza
# 5                                  Blotto
# 6                    Italian Family Pizza
# 7                           Central Pizza
# 8                The Independent Pizzeria
# 9                                    Moto
# 10       Boca Argentine Bakery & Pizzeria
# 11                            Zeeks Pizza
# 12                                Rocco's
# 13                   Serious Pie Downtown
# 14                   Johnny Mo's Pizzeria
# 15                               Southpaw
# 16  Olympia Pizza and Spaghetti House III
# 17                               Mioposto
# 18                     Nine Pies Pizzeria
# 19           Via Tribunali - Capitol Hill
#
#                                             image_url  is_closed  \
# 0   https://s3-media4.fl.yelpcdn.com/bphoto/uMrdEj...      False
# 1   https://s3-media1.fl.yelpcdn.com/bphoto/9tK83_...      False
# 2   https://s3-media4.fl.yelpcdn.com/bphoto/HlYYBT...      False
# 3   https://s3-media3.fl.yelpcdn.com/bphoto/07DoPF...      False
# 4   https://s3-media4.fl.yelpcdn.com/bphoto/LEL1qj...      False
# 5   https://s3-media3.fl.yelpcdn.com/bphoto/Q4Y1Cw...      False
# 6   https://s3-media2.fl.yelpcdn.com/bphoto/SgiSrJ...      False
# 7   https://s3-media4.fl.yelpcdn.com/bphoto/DE4G4e...      False
# 8   https://s3-media4.fl.yelpcdn.com/bphoto/4gIuis...      False
# 9   https://s3-media2.fl.yelpcdn.com/bphoto/FBmvjy...      False
# 10  https://s3-media1.fl.yelpcdn.com/bphoto/5MPTtV...      False
# 11  https://s3-media4.fl.yelpcdn.com/bphoto/qmf4kA...      False
# 12  https://s3-media3.fl.yelpcdn.com/bphoto/pf6jTK...      False
# 13  https://s3-media2.fl.yelpcdn.com/bphoto/dy0pJ5...      False
# 14  https://s3-media4.fl.yelpcdn.com/bphoto/8IAnDP...      False
# 15  https://s3-media2.fl.yelpcdn.com/bphoto/rJXKQ5...      False
# 16  https://s3-media1.fl.yelpcdn.com/bphoto/KvTgMA...      False
# 17  https://s3-media1.fl.yelpcdn.com/bphoto/gWBw_l...      False
# 18  https://s3-media4.fl.yelpcdn.com/bphoto/S-C1c1...      False
# 19  https://s3-media4.fl.yelpcdn.com/bphoto/8nqcG7...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/guerilla-pizza-kitche...             1
# 1   https://www.yelp.com/biz/humble-pie-seattle?ad...           349
# 2   https://www.yelp.com/biz/cornelly-seattle?adju...            86
# 3   https://www.yelp.com/biz/bar-cotto-seattle?adj...           330
# 4   https://www.yelp.com/biz/hot-mamas-pizza-seatt...           925
# 5   https://www.yelp.com/biz/blotto-seattle?adjust...            30
# 6   https://www.yelp.com/biz/italian-family-pizza-...           972
# 7   https://www.yelp.com/biz/central-pizza-seattle...           191
# 8   https://www.yelp.com/biz/the-independent-pizze...           179
# 9   https://www.yelp.com/biz/moto-seattle?adjust_c...           110
# 10  https://www.yelp.com/biz/boca-argentine-bakery...            16
# 11  https://www.yelp.com/biz/zeeks-pizza-seattle-1...            89
# 12  https://www.yelp.com/biz/roccos-seattle?adjust...          1686
# 13  https://www.yelp.com/biz/serious-pie-downtown-...          4399
# 14  https://www.yelp.com/biz/johnny-mos-pizzeria-s...           120
# 15  https://www.yelp.com/biz/southpaw-seattle?adju...            77
# 16  https://www.yelp.com/biz/olympia-pizza-and-spa...           287
# 17  https://www.yelp.com/biz/mioposto-seattle-7?ad...           380
# 18  https://www.yelp.com/biz/nine-pies-pizzeria-se...           139
# 19  https://www.yelp.com/biz/via-tribunali-capitol...           616
#
#                                            categories  rating  \
# 0   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     5.0
# 1              [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 2   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 3   [{'alias': 'bars', 'title': 'Bars'}, {'alias':...     4.5
# 4              [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 5              [{'alias': 'pizza', 'title': 'Pizza'}]     5.0
# 6   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 7   [{'alias': 'bars', 'title': 'Bars'}, {'alias':...     4.0
# 8   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 9   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     5.0
# 10  [{'alias': 'argentine', 'title': 'Argentine'},...     4.5
# 11             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 12  [{'alias': 'bars', 'title': 'Bars'}, {'alias':...     4.0
# 13  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 14             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 15  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 16  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 17  [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.0
# 18  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 19  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
#
#                                           coordinates        transactions  \
# 0   {'latitude': 47.608127, 'longitude': -122.302435}                  []
# 1   {'latitude': 47.5976491915013, 'longitude': -1...          [delivery]
# 2   {'latitude': 47.624577, 'longitude': -122.325577}  [delivery, pickup]
# 3   {'latitude': 47.6146934, 'longitude': -122.312...          [delivery]
# 4   {'latitude': 47.615379179632, 'longitude': -12...          [delivery]
# 5     {'latitude': 47.61849, 'longitude': -122.31664}                  []
# 6     {'latitude': 47.60937, 'longitude': -122.32546}  [delivery, pickup]
# 7   {'latitude': 47.598976, 'longitude': -122.294685}  [delivery, pickup]
# 8   {'latitude': 47.636044, 'longitude': -122.277377}          [delivery]
# 9     {'latitude': 47.56207, 'longitude': -122.38509}          [delivery]
# 10    {'latitude': 47.62278, 'longitude': -122.32064}                  []
# 11  {'latitude': 47.6245449, 'longitude': -122.308...  [delivery, pickup]
# 12  {'latitude': 47.614470434736106, 'longitude': ...  [delivery, pickup]
# 13  {'latitude': 47.61304626911818, 'longitude': -...  [delivery, pickup]
# 14    {'latitude': 47.65142, 'longitude': -122.32083}  [delivery, pickup]
# 15    {'latitude': 47.61118, 'longitude': -122.31654}  [delivery, pickup]
# 16   {'latitude': 47.62383, 'longitude': -122.312445}          [delivery]
# 17    {'latitude': 47.57802, 'longitude': -122.28808}  [delivery, pickup]
# 18  {'latitude': 47.5679230496817, 'longitude': -1...  [delivery, pickup]
# 19    {'latitude': 47.61386, 'longitude': -122.31986}  [delivery, pickup]
#
#                                              location         phone  \
# 0   {'address1': '2300 E Cherry St', 'address2': '...
# 1   {'address1': '525 Rainier Ave S', 'address2': ...  +12063295133
# 2   {'address1': '601 Summit Ave E', 'address2': '...
# 3   {'address1': '1546 15th Ave', 'address2': '', ...  +12068388081
# 4   {'address1': '700 E Pine St', 'address2': '', ...  +12063226444
# 5   {'address1': '1830 12th Ave', 'address2': '', ...  +12064031809
# 6   {'address1': '1028 Madison St', 'address2': No...  +12065380040
# 7   {'address1': '2901 S Jackson St', 'address2': ...  +12066026333
# 8   {'address1': '4235 E Madison St', 'address2': ...  +12068606110
# 9   {'address1': '4526 42nd Ave SW', 'address2': '...  +12064208880
# 10  {'address1': '426 Broadway E', 'address2': '',...
# 11  {'address1': '1830 E Mercer St', 'address2': N...  +12062858646
# 12  {'address1': '2312 2nd Ave', 'address2': '', '...  +12063974210
# 13  {'address1': '2001 4th Ave', 'address2': None,...  +12068387388
# 14  {'address1': '3272 Fuhrman Ave E', 'address2':...  +12068226272
# 15  {'address1': '926 12th Ave', 'address2': '', '...  +12063235278
# 16  {'address1': '516 15th Ave E', 'address2': '',...  +12063294500
# 17  {'address1': '3601 S McClellan St', 'address2'...  +12067603400
# 18  {'address1': '3861 1st Ave S', 'address2': Non...  +12065820777
# 19  {'address1': '913 E Pike St', 'address2': '', ...  +12063229234
#
#      display_phone     distance price
# 0                    749.173113   NaN
# 1   (206) 329-5133  2166.834011    $$
# 2                   2578.701393   NaN
# 3   (206) 838-8081  1292.526796    $$
# 4   (206) 322-6444  2080.359405     $
# 5   (206) 403-1809  1686.862176   NaN
# 6   (206) 538-0040  2271.307105    $$
# 7   (206) 602-6333  1571.867438    $$
# 8   (206) 860-6110  2897.252844    $$
# 9   (206) 420-8880  8784.075722   NaN
# 10                  2152.679112   NaN
# 11  (206) 285-8646  1554.213861   NaN
# 12  (206) 397-4210  3779.508800    $$
# 13  (206) 838-7388  3348.309276    $$
# 14  (206) 822-6272  4658.301257    $$
# 15  (206) 323-5278  1576.874272    $$
# 16  (206) 329-4500  1732.874383    $$
# 17  (206) 760-3400  3941.663432    $$
# 18  (206) 582-0777  5833.910009    $$
# 19  (206) 322-9234  1818.629179    $$

# %%
results['total']
# Out:
# 844

# %%
results['region']
# Out:
# {'center': {'longitude': -122.29568481445312, 'latitude': 47.61309534151991}}

# %%
results_per_page = len(results['businesses'])

# %%
results_per_page
# Out:
# 20

# %%
## How many results total?
# Use math.ceil to round up for the total number of pages of results.
import math
n_pages= math.ceil(results['total']/results_per_page)
n_pages
# Out:
# 43

# %% [markdown]
# - Where is the actual data we want to save?

# %%
# lets save the data

# Check if Json file exists and create it if it does not

if os.path.isfile(JSON_FILE)==False:
    # file does not exist so print message and create empty file
    print(" The file does not exist. Creating empty file.")
    with open(JSON_FILE,'w') as f:
        json.dump(results['businesses'],f)
# if file exists
else:
    print("File already exists")
# Out:
#  The file does not exist. Creating empty file.

# %%
for i in tqdm_notebook( range(1,n_pages+1)):
    ## The block of code we want to TRY to run
        
        
        ## Read in results in progress file and check the length
        with open(JSON_FILE) as f:
            prev_results = json.load(f)
        
        ## save number of results for to use as offset
        n_results = len(prev_results)
        
        
        ## use n_results as the OFFSET 
        results = yelp.search_query(term = term,location=location,offset=n_results)

        ## append new results and save to file
        
        prev_results.extend(results['businesses'])
        with open(JSON_FILE,'w') as f:
            json.dump(prev_results,f)
            
    ## What to do if we get an error/exception.
# Out:
#   0%|          | 0/43 [00:00<?, ?it/s]

# %%
df = pd.read_json(JSON_FILE)
df
# Out:
#                          id                                 alias  \
# 0    t-Z9bvmlgUyDtomGmttrUQ        guerilla-pizza-kitchen-seattle
# 1    Wi6LFkjIausYj277ru6pqg                    humble-pie-seattle
# 2    EwrAoy7XbX8nfemZdDvupA                      cornelly-seattle
# 3    fxyHWmfzcdjImgQ_UYHoTw                     bar-cotto-seattle
# 4    M9xzvwgK58T0w7wvXedvuQ               hot-mamas-pizza-seattle
# ..                      ...                                   ...
# 839  zXasSoalA8ALUs_uiKt3fg                grateful-bread-seattle
# 840  8S3qU0TGMJDyj4KHBmxlaw                      pho-tai-kirkland
# 841  rcDbUcs83gvoRxhaTmFfnQ  cypress-lounge-and-wine-bar-bellevue
# 842  3cLNDJ2vI29LWNvU7vVIuQ           capital-one-café-bellevue-2
# 843  i8mygke4ckycOudTO_3UQQ                café-cesura-bellevue-4
#
#                           name  \
# 0       Guerilla Pizza Kitchen
# 1                   Humble Pie
# 2                     Cornelly
# 3                    Bar Cotto
# 4             Hot Mama's Pizza
# ..                         ...
# 839             Grateful Bread
# 840                    Pho Tai
# 841  Cypress Lounge & Wine Bar
# 842           Capital One Café
# 843                Café Cesura
#
#                                              image_url  is_closed  \
# 0    https://s3-media4.fl.yelpcdn.com/bphoto/uMrdEj...      False
# 1    https://s3-media1.fl.yelpcdn.com/bphoto/9tK83_...      False
# 2    https://s3-media4.fl.yelpcdn.com/bphoto/HlYYBT...      False
# 3    https://s3-media3.fl.yelpcdn.com/bphoto/07DoPF...      False
# 4    https://s3-media4.fl.yelpcdn.com/bphoto/LEL1qj...      False
# ..                                                 ...        ...
# 839  https://s3-media1.fl.yelpcdn.com/bphoto/dw_z_D...      False
# 840  https://s3-media3.fl.yelpcdn.com/bphoto/tnvGkA...      False
# 841  https://s3-media2.fl.yelpcdn.com/bphoto/DsFhIb...      False
# 842  https://s3-media1.fl.yelpcdn.com/bphoto/-o6eAW...      False
# 843  https://s3-media3.fl.yelpcdn.com/bphoto/t6NpST...      False
#
#                                                    url  review_count  \
# 0    https://www.yelp.com/biz/guerilla-pizza-kitche...             1
# 1    https://www.yelp.com/biz/humble-pie-seattle?ad...           349
# 2    https://www.yelp.com/biz/cornelly-seattle?adju...            86
# 3    https://www.yelp.com/biz/bar-cotto-seattle?adj...           330
# 4    https://www.yelp.com/biz/hot-mamas-pizza-seatt...           925
# ..                                                 ...           ...
# 839  https://www.yelp.com/biz/grateful-bread-seattl...           261
# 840  https://www.yelp.com/biz/pho-tai-kirkland?adju...           187
# 841  https://www.yelp.com/biz/cypress-lounge-and-wi...            64
# 842  https://www.yelp.com/biz/capital-one-caf%C3%A9...            37
# 843  https://www.yelp.com/biz/caf%C3%A9-cesura-bell...           541
#
#                                             categories  rating  \
# 0    [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     5.0
# 1               [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 2    [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 3    [{'alias': 'bars', 'title': 'Bars'}, {'alias':...     4.5
# 4               [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# ..                                                 ...     ...
# 839  [{'alias': 'bakeries', 'title': 'Bakeries'}, {...     3.5
# 840  [{'alias': 'vietnamese', 'title': 'Vietnamese'...     3.5
# 841  [{'alias': 'wine_bars', 'title': 'Wine Bars'},...     3.5
# 842  [{'alias': 'banks', 'title': 'Banks & Credit U...     4.0
# 843  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     3.5
#
#                                            coordinates        transactions  \
# 0    {'latitude': 47.608127, 'longitude': -122.302435}                  []
# 1    {'latitude': 47.5976491915013, 'longitude': -1...          [delivery]
# 2    {'latitude': 47.624577, 'longitude': -122.325577}  [delivery, pickup]
# 3    {'latitude': 47.6146934, 'longitude': -122.312...          [delivery]
# 4    {'latitude': 47.615379179632, 'longitude': -12...          [delivery]
# ..                                                 ...                 ...
# 839     {'latitude': 47.67964, 'longitude': -122.2907}          [delivery]
# 840  {'latitude': 47.676215, 'longitude': -122.205084}  [pickup, delivery]
# 841  {'latitude': 47.6157033283809, 'longitude': -1...                  []
# 842  {'latitude': 47.6140799195084, 'longitude': -1...                  []
# 843  {'latitude': 47.6196463475606, 'longitude': -1...            [pickup]
#
#                                               location         phone  \
# 0    {'address1': '2300 E Cherry St', 'address2': '...
# 1    {'address1': '525 Rainier Ave S', 'address2': ...  +12063295133
# 2    {'address1': '601 Summit Ave E', 'address2': '...
# 3    {'address1': '1546 15th Ave', 'address2': '', ...  +12068388081
# 4    {'address1': '700 E Pine St', 'address2': '', ...  +12063226444
# ..                                                 ...           ...
# 839  {'address1': '7001 35th Ave NE', 'address2': '...  +12065253166
# 840  {'address1': '147 Park Ln', 'address2': '', 'a...  +14255765407
# 841  {'address1': '600 Bellevue Way NE', 'address2'...  +14256381000
# 842  {'address1': '400 Bellevue Way NE', 'address2'...  +14253720250
# 843  {'address1': '1015 108th Ave NE', 'address2': ...  +14259547277
#
#       display_phone     distance price
# 0                     749.173113   NaN
# 1    (206) 329-5133  2166.834011    $$
# 2                    2578.701393   NaN
# 3    (206) 838-8081  1292.526796    $$
# 4    (206) 322-6444  2080.359405     $
# ..              ...          ...   ...
# 839  (206) 525-3166  7417.526253     $
# 840  (425) 576-5407  9765.353049    $$
# 841  (425) 638-1000  7123.208902    $$
# 842  (425) 372-0250  7071.129218     $
# 843  (425) 954-7277  7466.233853     $
#
# [844 rows x 16 columns]

# %%
# check for any duplicates
df.duplicated(subset='id').sum()
# Out:
# 1

# %%
# remove duplicates if any
df.drop_duplicates(subset='id',inplace=True)

# %%
df.duplicated(subset='id').sum()
# Out:
# 0

# %%
## convert the filename to a .csv.gz
csv_file = JSON_FILE.replace('.json','.csv.gz')
csv_file
# Out:
# 'Data/Seattle-pizza.csv.gz'

# %%
## Save it as a compressed csv (to save space)
df.to_csv(csv_file,compression='gzip',index=False)

# %% [markdown]
# ## Bonus: compare filesize with os module's `os.path.getsize`

# %%
size_json = os.path.getsize(JSON_FILE)
size_csv_gz = os.path.getsize(JSON_FILE.replace('.json','.csv.gz'))

print(f'JSON FILE: {size_json:,} Bytes')
print(f'CSV.GZ FILE: {size_csv_gz:,} Bytes')

print(f'the csv.gz is {size_json/size_csv_gz} times smaller!')
# Out:
# JSON FILE: 823,059 Bytes
# CSV.GZ FILE: 118,767 Bytes
# the csv.gz is 6.930031069236404 times smaller!

# %% [markdown]
# ## Next Class: Processing the Results and Mapping
