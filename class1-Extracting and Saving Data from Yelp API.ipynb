# %% [markdown]
# # Part 1 - Extracting and Saving Data from Yelp API

# %% [markdown]
# ## Obective

# %% [markdown]
# - For this CodeAlong, we will be working with the Yelp API.
# - You will use the the Yelp API to search your home town for a cuisine type of your choice.
# - Next class, we will then use Plotly Express to create a map with the Mapbox API to visualize the results.

# %% [markdown]
# ## Tools You Will Use
# - Part 1:
#     - Yelp API:
#         - Getting Started:
#             - https://www.yelp.com/developers/documentation/v3/get_started
#
#     - `YelpAPI` python package
#         -  "YelpAPI": https://github.com/gfairchild/yelpapi
# - Part 2:
#
#     - Plotly Express: https://plotly.com/python/getting-started/
#         - With Mapbox API: https://www.mapbox.com/
#         - `px.scatter_mapbox` [Documentation](https://plotly.com/python/scattermapbox/):

# %% [markdown]
# ### Applying Code From
# - Efficient API Calls Lesson Link: https://login.codingdojo.com/m/376/12529/88078

# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Additional Imports
import os, json, math, time
from yelpapi import YelpAPI
from tqdm.notebook import tqdm_notebook

# %%
# !pip install yelpapi
# Out:
# Requirement already satisfied: yelpapi in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (2.4.0)
# Requirement already satisfied: requests in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from yelpapi) (2.28.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from requests->yelpapi) (2.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from requests->yelpapi) (1.26.8)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from requests->yelpapi) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from requests->yelpapi) (2022.6.15)

# %% [markdown]
# ## 1. Registering for Required APIs

# %% [markdown]
# - Yelp: https://www.yelp.com/developers/documentation/v3/get_started

# %% [markdown]
# > Check the official API documentation to know what arguments we can search for: https://www.yelp.com/developers/documentation/v3/business_search

# %% [markdown]
# ### Load Credentials and Create Yelp API Object

# %%
# Load API Credentials
with open('/Users/purvikansara/.secret/yelp_api.json','r') as f:
    login = json.load(f)

# %%
login.keys()
# Out:
# dict_keys(['Client-ID', 'API Key'])

# %%
# Instantiate YelpAPI Variable
yelp = YelpAPI(login['API Key'],timeout_s= 5.0)

# %% [markdown]
# ### Define Search Terms and File Paths

# %%
# set our API call parameters and filename before the first call
location = 'Seattle, WA 98122'
term = 'pizza'

# %%
## Specify fodler for saving data

FOLDER ='Data/'
os.makedirs(FOLDER,exist_ok=True)

# %%
location.split(',')[0]
# Out:
# 'Seattle'

# %%
n=1
f"{term}{n}.csv"
# Out:
# 'pizza1.csv'

# %%
# Specifying JSON_FILE filename (can include a folder)
JSON_FILE = FOLDER+f"{location.split(',')[0]}-{term}.json"

# %%
JSON_FILE
# Out:
# 'Data/Seattle-pizza.json'

# %% [markdown]
# ### Check if Json File exists and Create it if it doesn't

# %%
## Check if JSON_FILE exists
file_exists = os.path.isfile(JSON_FILE)

## If it does not exist: 
if file_exists ==False:
    ## CREATE ANY NEEDED FOLDERS
    # Get the Folder Name only
    folder = os.path.dirname(JSON_FILE)
    
    ## If JSON_FILE included a folder:
    if len(folder)>0:
        # create the folder
        os.makedirs(folder,exist_ok=True)
        
    ## INFORM USER AND SAVE EMPTY LIST
    print(f"[i] {JSON_FILE} not found. Saving empty list to file.")
    
    
    ## save the first page of results
    with open(JSON_FILE,'w')as f:
        json.dump([],f)
        
## If it exists, inform user
else:
       print(f"[i] {JSON_FILE} already exists.")
# Out:
# [i] Data/Seattle-pizza.json not found. Saving empty list to file.

# %% [markdown]
# ![png](Figures/question.png)

# %% [markdown]
# ### Make the first API call to get the first page of data

# %% [markdown]
# - We will use this first result to check:
#     - how many total results there are?
#     - Where is the actual data we want to save?
#     - how many results do we get at a time?

# %%
# use our yelp variable's search_query method to perform our API call
results = yelp.search_query(term=term,location = location)

# %%
type(results)
# Out:
# dict

# %%
## How many results total?
len(results)
# Out:
# 3

# %%
results.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
results['businesses']
# Out:
# [{'id': 'EwrAoy7XbX8nfemZdDvupA',
#   'alias': 'cornelly-seattle',
#   'name': 'Cornelly',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/HlYYBTxylVQf6C-WZy-Ghw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/cornelly-seattle?adjust_creative=r8Qlusnw5U_OXTmzDH90Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=r8Qlusnw5U_OXTmzDH90Ug',
#   'review_count': 101,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'salad', 'title': 'Salad'},
#    {'alias': 'pastashops', 'title': 'Pasta Shops'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.624577, 'longitude': -122.325577},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '601 Summit Ave E',
#    'address2': '',
#    'address3': None,
#    'city': 'Seattle',
#    'zip_code': '98102',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['601 Summit Ave E', 'Seattle, WA 98102']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 2578.701392645466},
#  {'id': 'fxyHWmfzcdjImgQ_UYHoTw',
#   'alias': 'bar-cotto-seattle',
#   'name': 'Bar Cotto',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/07DoPFljyge3LApw8qW-cg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bar-cotto-seattle?adjust_creative=r8Qlusnw5U_OXTmzDH90Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=r8Qlusnw5U_OXTmzDH90Ug',
#   'review_count': 343,
#   'categories': [{'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.6146934, 'longitude': -122.3127642},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1546 15th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98122',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['1546 15th Ave', 'Seattle, WA 98122']},
#   'phone': '+12068388081',
#   'display_phone': '(206) 838-8081',
#   'distance': 1292.526796461093},
#  {'id': 't-Z9bvmlgUyDtomGmttrUQ',
#   'alias': 'guerilla-pizza-kitchen-seattle',
#   'name': 'Guerilla Pizza Kitchen',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/uMrdEjc9J_4Tb1PtAb71UA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/guerilla-pizza-kitchen-seattle?adjust_creative=r8Qlusnw5U_OXTmzDH90Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=r8Qlusnw5U_OXTmzDH90Ug',
#   'review_count': 1,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'popuprestaurants', 'title': 'Pop-Up Restaurants'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 47.608127, 'longitude': -122.302435},
#   'transactions': [],
#   'location': {'address1': '2300 E Cherry St',
#    'address2': '',
#    'address3': None,
#    'city': 'Seattle',
#    'zip_code': '98122',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['2300 E Cherry St', 'Seattle, WA 98122']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 749.1731129459927},
#  {'id': 'M9xzvwgK58T0w7wvXedvuQ',
#   'alias': 'hot-mamas-pizza-seattle',
#   'name': "Hot Mama's Pizza",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/LEL1qjUtdXO8aUPV9U-WwQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/hot-mamas-pizza-seattle?adjust_creative=r8Qlusnw5U_OXTmzDH90Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=r8Qlusnw5U_OXTmzDH90Ug',
#   'review_count': 964,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.615379179632, 'longitude': -122.32323073437},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '700 E Pine St',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98122',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['700 E Pine St', 'Seattle, WA 98122']},
#   'phone': '+12063226444',
#   'display_phone': '(206) 322-6444',
#   'distance': 2080.359405276959},
#  {'id': 'et4eWK49x5od4lfqCukG6w',
#   'alias': 'central-pizza-seattle',
#   'name': 'Central Pizza',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/DE4G4eOtt4lcBN_PJtaniw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/central-pizza-seattle?adjust_creative=r8Qlusnw5U_OXTmzDH90Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=r8Qlusnw5U_OXTmzDH90Ug',
#   'review_count': 205,
#   'categories': [{'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.598976, 'longitude': -122.294685},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '2901 S Jackson St',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98144',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['2901 S Jackson St', 'Seattle, WA 98144']},
#   'phone': '+12066026333',
#   'display_phone': '(206) 602-6333',
#   'distance': 1571.8674380755467},
#  {'id': 'FVbwpNA1uZEGiM02N4XtUg',
#   'alias': 'blotto-seattle',
#   'name': 'Blotto',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Q4Y1CwKmapk89MYpoxCu7Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/blotto-seattle?adjust_creative=r8Qlusnw5U_OXTmzDH90Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=r8Qlusnw5U_OXTmzDH90Ug',
#   'review_count': 40,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.61849, 'longitude': -122.31664},
#   'transactions': [],
#   'location': {'address1': '1830 12th Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Seattle',
#    'zip_code': '98122',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['1830 12th Ave', 'Seattle, WA 98122']},
#   'phone': '+12064031809',
#   'display_phone': '(206) 403-1809',
#   'distance': 1686.8621759079958},
#  {'id': 'ugTsEtjvwRhteac_6JcuPw',
#   'alias': 'italian-family-pizza-seattle',
#   'name': 'Italian Family Pizza',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SgiSrJxdCGbPZjnTZRrCYQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/italian-family-pizza-seattle?adjust_creative=r8Qlusnw5U_OXTmzDH90Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=r8Qlusnw5U_OXTmzDH90Ug',
#   'review_count': 1004,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.60937, 'longitude': -122.32546},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1028 Madison St',
#    'address2': None,
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98104',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['1028 Madison St', 'Seattle, WA 98104']},
#   'phone': '+12065380040',
#   'display_phone': '(206) 538-0040',
#   'distance': 2271.307105309817},
#  {'id': 'Wi6LFkjIausYj277ru6pqg',
#   'alias': 'humble-pie-seattle',
#   'name': 'Humble Pie',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/A08GOZ76GAAH6Sm_0_YAeQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/humble-pie-seattle?adjust_creative=r8Qlusnw5U_OXTmzDH90Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=r8Qlusnw5U_OXTmzDH90Ug',
#   'review_count': 362,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.5976491915013,
#    'longitude': -122.313305988361},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '525 Rainier Ave S',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98144',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['525 Rainier Ave S', 'Seattle, WA 98144']},
#   'phone': '+12063295133',
#   'display_phone': '(206) 329-5133',
#   'distance': 2166.834011449786},
#  {'id': 'IrohtoYjnAR_vc6w6CRCxA',
#   'alias': 'moto-seattle',
#   'name': 'Moto',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FBmvjyC1wH7-N_lIE_M_lQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/moto-seattle?adjust_creative=r8Qlusnw5U_OXTmzDH90Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=r8Qlusnw5U_OXTmzDH90Ug',
#   'review_count': 143,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.56207, 'longitude': -122.38509},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '4526 42nd Ave SW',
#    'address2': '',
#    'address3': None,
#    'city': 'Seattle',
#    'zip_code': '98116',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['4526 42nd Ave SW', 'Seattle, WA 98116']},
#   'phone': '+12064208880',
#   'display_phone': '(206) 420-8880',
#   'distance': 8784.07572205985},
#  {'id': 'kVqwgAjEPffEyMJSzpfM_A',
#   'alias': 'pagliacci-pizza-seattle-26',
#   'name': 'Pagliacci Pizza',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7thHN-i4t_OPPnDIHqYtig/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pagliacci-pizza-seattle-26?adjust_creative=r8Qlusnw5U_OXTmzDH90Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=r8Qlusnw5U_OXTmzDH90Ug',
#   'review_count': 98,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 47.6254949, 'longitude': -122.2928304},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '3015 E Madison St',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98112',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['3015 E Madison St', 'Seattle, WA 98112']},
#   'phone': '+12067261717',
#   'display_phone': '(206) 726-1717',
#   'distance': 1395.266331559967},
#  {'id': 'n6BLr6spgjVWqzUwmVx0bg',
#   'alias': 'johnny-mos-pizzeria-seattle',
#   'name': "Johnny Mo's Pizzeria",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/8IAnDPt0FWQNx9pLvuSbNg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/johnny-mos-pizzeria-seattle?adjust_creative=r8Qlusnw5U_OXTmzDH90Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=r8Qlusnw5U_OXTmzDH90Ug',
#   'review_count': 143,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.65142, 'longitude': -122.32083},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '3272 Fuhrman Ave E',
#    'address2': 'Ste 100',
#    'address3': None,
#    'city': 'Seattle',
#    'zip_code': '98102',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['3272 Fuhrman Ave E', 'Ste 100', 'Seattle, WA 98102']},
#   'phone': '+12068226272',
#   'display_phone': '(206) 822-6272',
#   'distance': 4658.301257471318},
#  {'id': '-FOAQv22SXtSBs7nptI3UA',
#   'alias': 'serious-pie-downtown-seattle-2',
#   'name': 'Serious Pie Downtown',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dy0pJ5hIEX5APuotqrgF7A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/serious-pie-downtown-seattle-2?adjust_creative=r8Qlusnw5U_OXTmzDH90Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=r8Qlusnw5U_OXTmzDH90Ug',
#   'review_count': 4485,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'salad', 'title': 'Salad'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.61304626911818,
#    'longitude': -122.34035259077139},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '2001 4th Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98121',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['2001 4th Ave', 'Seattle, WA 98121']},
#   'phone': '+12068387388',
#   'display_phone': '(206) 838-7388',
#   'distance': 3348.3092758278417},
#  {'id': 'GJdmwqqkC0nAQfX1qZM3ew',
#   'alias': 'olympia-pizza-and-spaghetti-house-iii-seattle',
#   'name': 'Olympia Pizza and Spaghetti House III',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KvTgMAozPm_HQGaBsfGELQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/olympia-pizza-and-spaghetti-house-iii-seattle?adjust_creative=r8Qlusnw5U_OXTmzDH90Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=r8Qlusnw5U_OXTmzDH90Ug',
#   'review_count': 297,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.62383, 'longitude': -122.312445},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '516 15th Ave E',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98112',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['516 15th Ave E', 'Seattle, WA 98112']},
#   'phone': '+12063294500',
#   'display_phone': '(206) 329-4500',
#   'distance': 1732.8743834241322},
#  {'id': 'cAFXng3Gr1cBCFkP1VIxng',
#   'alias': 'the-independent-pizzeria-seattle-2',
#   'name': 'The Independent Pizzeria',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/4gIuisTnhbj8O3O09yLcrg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-independent-pizzeria-seattle-2?adjust_creative=r8Qlusnw5U_OXTmzDH90Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=r8Qlusnw5U_OXTmzDH90Ug',
#   'review_count': 180,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.636044, 'longitude': -122.277377},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '4235 E Madison St',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98112',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['4235 E Madison St', 'Seattle, WA 98112']},
#   'phone': '+12068606110',
#   'display_phone': '(206) 860-6110',
#   'distance': 2897.2528438366567},
#  {'id': 'Ss_66zV-zhK_57_6MgV93w',
#   'alias': 'aglio-e-olio-seattle',
#   'name': 'Aglio e Olio',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/inrSl1hdg0l2L3mYz3-fVg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/aglio-e-olio-seattle?adjust_creative=r8Qlusnw5U_OXTmzDH90Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=r8Qlusnw5U_OXTmzDH90Ug',
#   'review_count': 273,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.62328027309258, 'longitude': -122.2959905},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '2743 E Madison St',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98112',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['2743 E Madison St', 'Seattle, WA 98112']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 1132.7432073522853},
#  {'id': 'wi-mbKEz4Ha1YYaOB8zHnw',
#   'alias': 'kōbo-pizza-seattle',
#   'name': 'Kōbo Pizza',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6et4T9Kn0bXCeJY8yBwS7w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/k%C5%8Dbo-pizza-seattle?adjust_creative=r8Qlusnw5U_OXTmzDH90Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=r8Qlusnw5U_OXTmzDH90Ug',
#   'review_count': 32,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.6144, 'longitude': -122.32271},
#   'transactions': [],
#   'location': {'address1': '714 E Pike St',
#    'address2': None,
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98122',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['714 E Pike St', 'Seattle, WA 98122']},
#   'phone': '+12536930207',
#   'display_phone': '(253) 693-0207',
#   'distance': 2025.13939581725},
#  {'id': '1rkgyfwzXG7qSdVZdfRt7g',
#   'alias': 'roccos-seattle',
#   'name': "Rocco's",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/AWBXTETwVoCALRNEO_f3eQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/roccos-seattle?adjust_creative=r8Qlusnw5U_OXTmzDH90Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=r8Qlusnw5U_OXTmzDH90Ug',
#   'review_count': 1748,
#   'categories': [{'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.614470434736106,
#    'longitude': -122.34606443927872},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '2312 2nd Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98121',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['2312 2nd Ave', 'Seattle, WA 98121']},
#   'phone': '+12063974210',
#   'display_phone': '(206) 397-4210',
#   'distance': 3779.508799794575},
#  {'id': 'PpAiLhErwd08QhPb06_-hA',
#   'alias': 'mioposto-seattle-7',
#   'name': 'Mioposto',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gWBw_lWXRC-95u0hh796mg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mioposto-seattle-7?adjust_creative=r8Qlusnw5U_OXTmzDH90Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=r8Qlusnw5U_OXTmzDH90Ug',
#   'review_count': 395,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.57802, 'longitude': -122.28808},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '3601 S McClellan St',
#    'address2': None,
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98144',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['3601 S McClellan St', 'Seattle, WA 98144']},
#   'phone': '+12067603400',
#   'display_phone': '(206) 760-3400',
#   'distance': 3941.6634321994184},
#  {'id': 'HeJP0ZS0tCCn-X9ezYSz3g',
#   'alias': 'ian-s-pizza-on-the-hill-seattle',
#   'name': 'Ian’s Pizza on the Hill',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gD-SKufIg_thSEXBDpDtng/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ian-s-pizza-on-the-hill-seattle?adjust_creative=r8Qlusnw5U_OXTmzDH90Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=r8Qlusnw5U_OXTmzDH90Ug',
#   'review_count': 300,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'hotdogs', 'title': 'Fast Food'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.615894, 'longitude': -122.320476},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '1620 Broadway',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98122',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['1620 Broadway', 'Seattle, WA 98122']},
#   'phone': '+12066594721',
#   'display_phone': '(206) 659-4721',
#   'distance': 1884.1780309728},
#  {'id': 'bkA3jfO2ej3pjAUMZWihGg',
#   'alias': 'pagliacci-pizza-seattle-32',
#   'name': 'Pagliacci Pizza',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7EHIhiw3imE4BXoZeXS0OA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pagliacci-pizza-seattle-32?adjust_creative=r8Qlusnw5U_OXTmzDH90Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=r8Qlusnw5U_OXTmzDH90Ug',
#   'review_count': 40,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.613922, 'longitude': -122.326006},
#   'transactions': [],
#   'location': {'address1': '415 E Pike St',
#    'address2': '',
#    'address3': None,
#    'city': 'Seattle',
#    'zip_code': '98122',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['415 E Pike St', 'Seattle, WA 98122']},
#   'phone': '+12067261717',
#   'display_phone': '(206) 726-1717',
#   'distance': 2274.720677854956}]

# %%
results['total']
# Out:
# 856

# %%
pd.DataFrame(results['businesses'])
# Out:
#                         id                                          alias  \
# 0   EwrAoy7XbX8nfemZdDvupA                               cornelly-seattle
# 1   fxyHWmfzcdjImgQ_UYHoTw                              bar-cotto-seattle
# 2   t-Z9bvmlgUyDtomGmttrUQ                 guerilla-pizza-kitchen-seattle
# 3   M9xzvwgK58T0w7wvXedvuQ                        hot-mamas-pizza-seattle
# 4   et4eWK49x5od4lfqCukG6w                          central-pizza-seattle
# 5   FVbwpNA1uZEGiM02N4XtUg                                 blotto-seattle
# 6   ugTsEtjvwRhteac_6JcuPw                   italian-family-pizza-seattle
# 7   Wi6LFkjIausYj277ru6pqg                             humble-pie-seattle
# 8   IrohtoYjnAR_vc6w6CRCxA                                   moto-seattle
# 9   kVqwgAjEPffEyMJSzpfM_A                     pagliacci-pizza-seattle-26
# 10  n6BLr6spgjVWqzUwmVx0bg                    johnny-mos-pizzeria-seattle
# 11  -FOAQv22SXtSBs7nptI3UA                 serious-pie-downtown-seattle-2
# 12  GJdmwqqkC0nAQfX1qZM3ew  olympia-pizza-and-spaghetti-house-iii-seattle
# 13  cAFXng3Gr1cBCFkP1VIxng             the-independent-pizzeria-seattle-2
# 14  Ss_66zV-zhK_57_6MgV93w                           aglio-e-olio-seattle
# 15  wi-mbKEz4Ha1YYaOB8zHnw                             kōbo-pizza-seattle
# 16  1rkgyfwzXG7qSdVZdfRt7g                                 roccos-seattle
# 17  PpAiLhErwd08QhPb06_-hA                             mioposto-seattle-7
# 18  HeJP0ZS0tCCn-X9ezYSz3g                ian-s-pizza-on-the-hill-seattle
# 19  bkA3jfO2ej3pjAUMZWihGg                     pagliacci-pizza-seattle-32
#
#                                      name  \
# 0                                Cornelly
# 1                               Bar Cotto
# 2                  Guerilla Pizza Kitchen
# 3                        Hot Mama's Pizza
# 4                           Central Pizza
# 5                                  Blotto
# 6                    Italian Family Pizza
# 7                              Humble Pie
# 8                                    Moto
# 9                         Pagliacci Pizza
# 10                   Johnny Mo's Pizzeria
# 11                   Serious Pie Downtown
# 12  Olympia Pizza and Spaghetti House III
# 13               The Independent Pizzeria
# 14                           Aglio e Olio
# 15                             Kōbo Pizza
# 16                                Rocco's
# 17                               Mioposto
# 18                Ian’s Pizza on the Hill
# 19                        Pagliacci Pizza
#
#                                             image_url  is_closed  \
# 0   https://s3-media4.fl.yelpcdn.com/bphoto/HlYYBT...      False
# 1   https://s3-media3.fl.yelpcdn.com/bphoto/07DoPF...      False
# 2   https://s3-media4.fl.yelpcdn.com/bphoto/uMrdEj...      False
# 3   https://s3-media4.fl.yelpcdn.com/bphoto/LEL1qj...      False
# 4   https://s3-media4.fl.yelpcdn.com/bphoto/DE4G4e...      False
# 5   https://s3-media3.fl.yelpcdn.com/bphoto/Q4Y1Cw...      False
# 6   https://s3-media2.fl.yelpcdn.com/bphoto/SgiSrJ...      False
# 7   https://s3-media4.fl.yelpcdn.com/bphoto/A08GOZ...      False
# 8   https://s3-media2.fl.yelpcdn.com/bphoto/FBmvjy...      False
# 9   https://s3-media3.fl.yelpcdn.com/bphoto/7thHN-...      False
# 10  https://s3-media4.fl.yelpcdn.com/bphoto/8IAnDP...      False
# 11  https://s3-media2.fl.yelpcdn.com/bphoto/dy0pJ5...      False
# 12  https://s3-media1.fl.yelpcdn.com/bphoto/KvTgMA...      False
# 13  https://s3-media4.fl.yelpcdn.com/bphoto/4gIuis...      False
# 14  https://s3-media2.fl.yelpcdn.com/bphoto/inrSl1...      False
# 15  https://s3-media1.fl.yelpcdn.com/bphoto/6et4T9...      False
# 16  https://s3-media3.fl.yelpcdn.com/bphoto/AWBXTE...      False
# 17  https://s3-media1.fl.yelpcdn.com/bphoto/gWBw_l...      False
# 18  https://s3-media1.fl.yelpcdn.com/bphoto/gD-SKu...      False
# 19  https://s3-media1.fl.yelpcdn.com/bphoto/7EHIhi...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/cornelly-seattle?adju...           101
# 1   https://www.yelp.com/biz/bar-cotto-seattle?adj...           343
# 2   https://www.yelp.com/biz/guerilla-pizza-kitche...             1
# 3   https://www.yelp.com/biz/hot-mamas-pizza-seatt...           964
# 4   https://www.yelp.com/biz/central-pizza-seattle...           205
# 5   https://www.yelp.com/biz/blotto-seattle?adjust...            40
# 6   https://www.yelp.com/biz/italian-family-pizza-...          1004
# 7   https://www.yelp.com/biz/humble-pie-seattle?ad...           362
# 8   https://www.yelp.com/biz/moto-seattle?adjust_c...           143
# 9   https://www.yelp.com/biz/pagliacci-pizza-seatt...            98
# 10  https://www.yelp.com/biz/johnny-mos-pizzeria-s...           143
# 11  https://www.yelp.com/biz/serious-pie-downtown-...          4485
# 12  https://www.yelp.com/biz/olympia-pizza-and-spa...           297
# 13  https://www.yelp.com/biz/the-independent-pizze...           180
# 14  https://www.yelp.com/biz/aglio-e-olio-seattle?...           273
# 15  https://www.yelp.com/biz/k%C5%8Dbo-pizza-seatt...            32
# 16  https://www.yelp.com/biz/roccos-seattle?adjust...          1748
# 17  https://www.yelp.com/biz/mioposto-seattle-7?ad...           395
# 18  https://www.yelp.com/biz/ian-s-pizza-on-the-hi...           300
# 19  https://www.yelp.com/biz/pagliacci-pizza-seatt...            40
#
#                                            categories  rating  \
# 0   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 1   [{'alias': 'bars', 'title': 'Bars'}, {'alias':...     4.5
# 2   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     5.0
# 3              [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 4   [{'alias': 'bars', 'title': 'Bars'}, {'alias':...     4.0
# 5              [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 6   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 7              [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 8   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 9              [{'alias': 'pizza', 'title': 'Pizza'}]     3.5
# 10             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 11  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 12  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 13  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 14  [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.5
# 15             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 16  [{'alias': 'bars', 'title': 'Bars'}, {'alias':...     4.0
# 17  [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.0
# 18  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 19             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
#
#                                           coordinates        transactions  \
# 0   {'latitude': 47.624577, 'longitude': -122.325577}  [pickup, delivery]
# 1   {'latitude': 47.6146934, 'longitude': -122.312...  [pickup, delivery]
# 2   {'latitude': 47.608127, 'longitude': -122.302435}                  []
# 3   {'latitude': 47.615379179632, 'longitude': -12...          [delivery]
# 4   {'latitude': 47.598976, 'longitude': -122.294685}  [pickup, delivery]
# 5     {'latitude': 47.61849, 'longitude': -122.31664}                  []
# 6     {'latitude': 47.60937, 'longitude': -122.32546}  [pickup, delivery]
# 7   {'latitude': 47.5976491915013, 'longitude': -1...          [delivery]
# 8     {'latitude': 47.56207, 'longitude': -122.38509}          [delivery]
# 9   {'latitude': 47.6254949, 'longitude': -122.292...          [delivery]
# 10    {'latitude': 47.65142, 'longitude': -122.32083}  [pickup, delivery]
# 11  {'latitude': 47.61304626911818, 'longitude': -...  [pickup, delivery]
# 12   {'latitude': 47.62383, 'longitude': -122.312445}          [delivery]
# 13  {'latitude': 47.636044, 'longitude': -122.277377}          [delivery]
# 14  {'latitude': 47.62328027309258, 'longitude': -...          [delivery]
# 15     {'latitude': 47.6144, 'longitude': -122.32271}                  []
# 16  {'latitude': 47.614470434736106, 'longitude': ...  [pickup, delivery]
# 17    {'latitude': 47.57802, 'longitude': -122.28808}  [pickup, delivery]
# 18  {'latitude': 47.615894, 'longitude': -122.320476}  [pickup, delivery]
# 19  {'latitude': 47.613922, 'longitude': -122.326006}                  []
#
#                                              location         phone  \
# 0   {'address1': '601 Summit Ave E', 'address2': '...
# 1   {'address1': '1546 15th Ave', 'address2': '', ...  +12068388081
# 2   {'address1': '2300 E Cherry St', 'address2': '...
# 3   {'address1': '700 E Pine St', 'address2': '', ...  +12063226444
# 4   {'address1': '2901 S Jackson St', 'address2': ...  +12066026333
# 5   {'address1': '1830 12th Ave', 'address2': '', ...  +12064031809
# 6   {'address1': '1028 Madison St', 'address2': No...  +12065380040
# 7   {'address1': '525 Rainier Ave S', 'address2': ...  +12063295133
# 8   {'address1': '4526 42nd Ave SW', 'address2': '...  +12064208880
# 9   {'address1': '3015 E Madison St', 'address2': ...  +12067261717
# 10  {'address1': '3272 Fuhrman Ave E', 'address2':...  +12068226272
# 11  {'address1': '2001 4th Ave', 'address2': None,...  +12068387388
# 12  {'address1': '516 15th Ave E', 'address2': '',...  +12063294500
# 13  {'address1': '4235 E Madison St', 'address2': ...  +12068606110
# 14  {'address1': '2743 E Madison St', 'address2': ...
# 15  {'address1': '714 E Pike St', 'address2': None...  +12536930207
# 16  {'address1': '2312 2nd Ave', 'address2': '', '...  +12063974210
# 17  {'address1': '3601 S McClellan St', 'address2'...  +12067603400
# 18  {'address1': '1620 Broadway', 'address2': '', ...  +12066594721
# 19  {'address1': '415 E Pike St', 'address2': '', ...  +12067261717
#
#      display_phone     distance price
# 0                   2578.701393   NaN
# 1   (206) 838-8081  1292.526796    $$
# 2                    749.173113   NaN
# 3   (206) 322-6444  2080.359405     $
# 4   (206) 602-6333  1571.867438    $$
# 5   (206) 403-1809  1686.862176   NaN
# 6   (206) 538-0040  2271.307105    $$
# 7   (206) 329-5133  2166.834011    $$
# 8   (206) 420-8880  8784.075722    $$
# 9   (206) 726-1717  1395.266332    $$
# 10  (206) 822-6272  4658.301257    $$
# 11  (206) 838-7388  3348.309276    $$
# 12  (206) 329-4500  1732.874383    $$
# 13  (206) 860-6110  2897.252844    $$
# 14                  1132.743207    $$
# 15  (253) 693-0207  2025.139396   NaN
# 16  (206) 397-4210  3779.508800    $$
# 17  (206) 760-3400  3941.663432    $$
# 18  (206) 659-4721  1884.178031     $
# 19  (206) 726-1717  2274.720678   NaN

# %% [markdown]
# - Where is the actual data we want to save?

# %%
## How many did we get the details for?
results_per_page = len(results['businesses'])

results_per_page
# Out:
# 20

# %% [markdown]
# - Calculate how many pages of results needed to cover the total_results

# %%
# Use math.ceil to round up for the total number of pages of results.
# Import additional packages for controlling our loop
import time, math
# Use math.ceil to round up for the total number of pages of results.
n_pages = math.ceil((results['total'])/ results_per_page)
n_pages
# Out:
# 43

# %%
for i in tqdm_notebook( range(1,n_pages+1)):
   # The block of code we want to TRY to run
    try:
        
        time.sleep(.2)
        
        ## Read in results in progress file and check the length
        with open(JSON_FILE, 'r') as f:
            previous_results = json.load(f)
            
        ## save number of results for to use as offset
        n_results = len(previous_results)
        
        
        ## use n_results as the OFFSET 
        results = yelp.search_query(location=location,
                                        term=term, 
                                        offset=n_results+1)

        ## append new results and save to file
        previous_results.extend(results['businesses'])

        with open(JSON_FILE,'w') as f:
            json.dump(previous_results,f)
            
    #What to do if we get an error/exception.
    except Exception as e: # saving the error message so we can print it.
        print('[!] ERROR: ',e)
# Out:
#   0%|          | 0/43 [00:00<?, ?it/s]

# %% [markdown]
# ![png](Figures/Poll_531.png)

# %% [markdown]
# ## Open the Final JSON File with Pandas

# %%
df = pd.read_json(JSON_FILE)
df.head()
# Out:
#                        id                           alias  \
# 0  fxyHWmfzcdjImgQ_UYHoTw               bar-cotto-seattle
# 1  t-Z9bvmlgUyDtomGmttrUQ  guerilla-pizza-kitchen-seattle
# 2  M9xzvwgK58T0w7wvXedvuQ         hot-mamas-pizza-seattle
# 3  et4eWK49x5od4lfqCukG6w           central-pizza-seattle
# 4  FVbwpNA1uZEGiM02N4XtUg                  blotto-seattle
#
#                      name                                          image_url  \
# 0               Bar Cotto  https://s3-media3.fl.yelpcdn.com/bphoto/07DoPF...
# 1  Guerilla Pizza Kitchen  https://s3-media4.fl.yelpcdn.com/bphoto/uMrdEj...
# 2        Hot Mama's Pizza  https://s3-media4.fl.yelpcdn.com/bphoto/LEL1qj...
# 3           Central Pizza  https://s3-media4.fl.yelpcdn.com/bphoto/DE4G4e...
# 4                  Blotto  https://s3-media3.fl.yelpcdn.com/bphoto/Q4Y1Cw...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/bar-cotto-seattle?adj...           343
# 1      False  https://www.yelp.com/biz/guerilla-pizza-kitche...             1
# 2      False  https://www.yelp.com/biz/hot-mamas-pizza-seatt...           964
# 3      False  https://www.yelp.com/biz/central-pizza-seattle...           205
# 4      False  https://www.yelp.com/biz/blotto-seattle?adjust...            40
#
#                                           categories  rating  \
# 0  [{'alias': 'bars', 'title': 'Bars'}, {'alias':...     4.5
# 1  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     5.0
# 2             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 3  [{'alias': 'bars', 'title': 'Bars'}, {'alias':...     4.0
# 4             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
#
#                                          coordinates        transactions  \
# 0  {'latitude': 47.6146934, 'longitude': -122.312...  [delivery, pickup]
# 1  {'latitude': 47.608127, 'longitude': -122.302435}                  []
# 2  {'latitude': 47.615379179632, 'longitude': -12...          [delivery]
# 3  {'latitude': 47.598976, 'longitude': -122.294685}  [delivery, pickup]
# 4    {'latitude': 47.61849, 'longitude': -122.31664}                  []
#
#   price                                           location         phone  \
# 0    $$  {'address1': '1546 15th Ave', 'address2': '', ...  +12068388081
# 1   NaN  {'address1': '2300 E Cherry St', 'address2': '...
# 2     $  {'address1': '700 E Pine St', 'address2': '', ...  +12063226444
# 3    $$  {'address1': '2901 S Jackson St', 'address2': ...  +12066026333
# 4   NaN  {'address1': '1830 12th Ave', 'address2': '', ...  +12064031809
#
#     display_phone     distance
# 0  (206) 838-8081  1292.526796
# 1                   749.173113
# 2  (206) 322-6444  2080.359405
# 3  (206) 602-6333  1571.867438
# 4  (206) 403-1809  1686.862176

# %%
## convert the filename to a .csv.gz
csv_file = JSON_FILE.replace('.json','.csv.gz')
csv_file
# Out:
# 'Data/Seattle-pizza.csv.gz'

# %%
## Save it as a compressed csv (to save space)
df.to_csv(csv_file, compression='gzip', index=False)

# %% [markdown]
# ## Bonus: compare filesize with os module's `os.path.getsize`

# %%
size_json = os.path.getsize(JSON_FILE)
size_csv_gz = os.path.getsize(JSON_FILE.replace('.json','.csv.gz'))

print(f'JSON FILE: {size_json:,} Bytes')
print(f'CSV.GZ FILE: {size_csv_gz:,} Bytes')

print(f'the csv.gz is {size_json/size_csv_gz} times smaller!')
# Out:
# JSON FILE: 834,834 Bytes
# CSV.GZ FILE: 120,084 Bytes
# the csv.gz is 6.952083541520936 times smaller!

# %% [markdown]
# ## Next Class: Processing the Results and Mapping
